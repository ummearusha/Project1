# %%
# Import the pathlib and csv library
# initial imports
import os
import pandas as pd
import matplotlib.pyplot as plt
import plotly.express as px
import hvplot.pandas
from pathlib import Path
from dotenv import load_dotenv
import random
import numpy as np
from MCForecastFantasy import MCSimulation

# %matplotlib inline

# %%
#os.getcwd()

# %%
#Setting the different CSV paths
data_2015_path = Path("./Resources/Historic_Data/fanduel_salary_production/NFL-HistoricalProduction_2015.csv")
data_2016_path = Path("./Resources/Historic_Data/fanduel_salary_production/NFL-HistoricalProduction_2016.csv")
data_2017_path = Path("./Resources/Historic_Data/fanduel_salary_production/NFL-HistoricalProduction_2017.csv")
data_2018_path = Path("./Resources/Historic_Data/fanduel_salary_production/NFL-HistoricalProduction_2018.csv")
data_2019_path = Path("./Resources/Historic_Data/fanduel_salary_production/NFL-HistoricalProduction_2019.csv")
data_2020_path = Path("./Resources/Historic_Data/fanduel_salary_production/NFL-HistoricalProduction_2020.csv")

# %%
#Reading in the CSV into into seperate dataframes
df_1 = pd.read_csv(data_2015_path)
df_2 = pd.read_csv(data_2016_path)
df_3 = pd.read_csv(data_2017_path)
df_4 = pd.read_csv(data_2018_path)
df_5 = pd.read_csv(data_2019_path)
df_6 = pd.read_csv(data_2020_path)

# %%
#Appending a column "Year" for each dataframe
df_1['Year'] = 2015

df_2['Year'] = 2016

df_3['Year'] = 2017

df_4['Year'] = 2018

df_5['Year'] = 2019

df_6['Year'] = 2020

# %%
#Concating all dataframes into one 
combined_df = pd.concat([df_1, df_2, df_3, df_4, df_5, df_6], axis='rows', join='inner')
combined_df.reset_index(inplace=True)

# %%
#Drop Columns
combined_df.drop(['DKSal','DK Points','index'], axis = 1, inplace=True)
#combined_df
combined_df['Year/Week'] = combined_df['Year']+combined_df['Week']/100
combined_df.round(decimals = 2)
combined_df['Year/Week'] = combined_df['Year/Week'].apply(str)

#sort dataframe by player and year/week
combined_df_2 = combined_df.sort_values(by=['Player', 'Year/Week'])

#rename columns
combined_df_2.rename(columns={'FD Points': "Points","FDSal": "Salary","P":"Position"},inplace= True)

#check for null values
combined_df_2.isnull().sum()
# Out:
# Position             0
# Player               0
# Week                 0
# Team                 0
# Opp                  0
# Opp Position Rank    0
# Salary               0
# Points               0
# Year                 0
# Year/Week            0
# dtype: int64

# %%
combined_df_2.dtypes
# Out:
# Position              object
# Player                object
# Week                   int64
# Team                  object
# Opp                   object
# Opp Position Rank      int64
# Salary                 int64
# Points               float64
# Year                   int64
# Year/Week             object
# dtype: object

# %%
#combined_df.dtypes

# %%
combined_df_2
# Out:
#       Position         Player  Week Team  Opp  Opp Position Rank  Salary  \
# 36606       WR     A.J. Brown     1  TEN  CLE                 11    5100
# 38173       WR     A.J. Brown     2  TEN  IND                 16    5400
# 39545       WR     A.J. Brown     3  TEN  JAX                 21    5200
# 35564       WR     A.J. Brown     4  TEN  ATL                 12    4700
# 38256       WR     A.J. Brown     5  TEN  BUF                  3    5600
# 38390       WR     A.J. Brown     6  TEN  DEN                  4    5400
# 36985       WR     A.J. Brown     7  TEN  LAC                  6    5300
# 37182       WR     A.J. Brown     8  TEN   TB                 30    5500
# 36846       WR     A.J. Brown     9  TEN  CAR                 14    5500
# 38839       WR     A.J. Brown    10  TEN   KC                  8    5500
# 35641       WR     A.J. Brown    12  TEN  JAX                 12    5300
# 37658       WR     A.J. Brown    13  TEN  IND                 19    5300
# 35360       WR     A.J. Brown    14  TEN  OAK                 22    5400
# 35644       WR     A.J. Brown    15  TEN  HOU                 19    6200
# 36175       WR     A.J. Brown    16  TEN   NO                 27    7200
# 35703       WR     A.J. Brown    17  TEN  HOU                 21    7200
# 45208       WR     A.J. Brown     1  TEN  DEN                  9    6700
# 46835       WR     A.J. Brown     2  TEN  JAX                 10    6600
# 47034       WR     A.J. Brown     3  TEN  MIN                 31    6500
# 44291       WR     A.J. Brown     5  TEN  BUF                 19    6500
# 44192       WR     A.J. Brown     6  TEN  HOU                 18    6500
# 44076       WR     A.J. Brown     7  TEN  PIT                 26    6800
# 44773       WR     A.J. Brown     8  TEN  CIN                 18    7500
# 44279       WR     A.J. Brown     9  TEN  CHI                  3    7600
# 46082       RB    A.J. Dillon     1   GB  MIN                 14    4700
# 45991       RB    A.J. Dillon     2   GB  DET                  6    4500
# 47129       RB    A.J. Dillon     3   GB   NO                 13    4500
# 46392       RB    A.J. Dillon     4   GB  ATL                 13    4500
# 45700       RB    A.J. Dillon     6   GB   TB                  8    4500
# 46186       RB    A.J. Dillon     7   GB  HOU                 32    4500
# ...        ...            ...   ...  ...  ...                ...     ...
# 41556       WR      Zay Jones     5  BUF  TEN                  7    4500
# 42911       WR      Zay Jones     7  OAK   GB                 15    4500
# 38260       WR      Zay Jones     8  OAK  HOU                 29    4500
# 38194       WR      Zay Jones     9  OAK  DET                 21    4800
# 39158       WR      Zay Jones    10  OAK  LAC                  8    4800
# 38187       WR      Zay Jones    11  OAK  CIN                 15    4800
# 39168       WR      Zay Jones    12  OAK  NYJ                 30    4800
# 38755       WR      Zay Jones    13  OAK   KC                  7    4700
# 39497       WR      Zay Jones    14  OAK  TEN                 17    4700
# 39500       WR      Zay Jones    15  OAK  JAX                 14    4700
# 38561       WR      Zay Jones    16  OAK  LAC                  3    4600
# 38473       WR      Zay Jones    17  OAK  DEN                  7    4700
# 46515       WR      Zay Jones     1   LV  CAR                 19    4800
# 45011       WR      Zay Jones     2   LV   NO                 19    4500
# 45450       WR      Zay Jones     3   LV   NE                 29    4500
# 45382       WR      Zay Jones     4   LV  BUF                 22    4500
# 46317       WR      Zay Jones     5   LV   KC                  1    4500
# 47962       WR      Zay Jones     7   LV   TB                  5    4500
# 48136       WR      Zay Jones     8   LV  CLE                 30    4500
# 48424       WR      Zay Jones     9   LV  LAC                 11    4600
# 6398        RB  Zurlon Tipton     4  IND  JAX                 26       0
# 4332        RB  Zurlon Tipton     5  IND  HOU                  0       0
# 6795        RB  Zurlon Tipton     6  IND   NE                 10       0
# 6964        RB  Zurlon Tipton     7  IND   NO                 27       0
# 7172        RB  Zurlon Tipton     8  IND  CAR                 20       0
# 7352        RB  Zurlon Tipton     9  IND  DEN                 13       0
# 7732        RB  Zurlon Tipton    11  IND  ATL                 25       0
# 4096        RB  Zurlon Tipton    13  IND  PIT                  2       0
# 2032        RB  Zurlon Tipton    14  IND  JAX                 18       0
# 4509        RB  Zurlon Tipton    15  IND  HOU                 19       0
#
#        Points  Year Year/Week
# 36606    11.5  2019   2019.01
# 38173     4.0  2019   2019.02
# 39545     0.9  2019   2019.03
# 35564    22.9  2019   2019.04
# 38256     3.7  2019   2019.05
# 38390     3.3  2019   2019.06
# 36985     9.2  2019   2019.07
# 37182     8.1  2019   2019.08
# 36846    10.1  2019   2019.09
# 38839     2.2  2019    2019.1
# 35641    21.5  2019   2019.12
# 37658     6.0  2019   2019.13
# 35360    31.1  2019   2019.14
# 35644    21.4  2019   2019.15
# 36175    14.8  2019   2019.16
# 35703    20.4  2019   2019.17
# 45208     6.4  2020   2020.01
# 46835     0.0  2020   2020.02
# 47034     0.0  2020   2020.03
# 44291    17.7  2020   2020.05
# 44192    20.1  2020   2020.06
# 44076    24.3  2020   2020.07
# 44773    10.4  2020   2020.08
# 44279    18.1  2020   2020.09
# 46082     1.4  2020   2020.01
# 45991     1.7  2020   2020.02
# 47129     0.0  2020   2020.03
# 46392     0.3  2020   2020.04
# 45700     3.1  2020   2020.06
# 46186     1.1  2020   2020.07
# ...       ...   ...       ...
# 41556     0.0  2019   2019.05
# 42911     0.0  2019   2019.07
# 38260     3.7  2019   2019.08
# 38194     3.9  2019   2019.09
# 39158     1.5  2019    2019.1
# 38187     4.0  2019   2019.11
# 39168     1.5  2019   2019.12
# 38755     2.4  2019   2019.13
# 39497     1.0  2019   2019.14
# 39500     1.0  2019   2019.15
# 38561     2.9  2019   2019.16
# 38473     3.1  2019   2019.17
# 46515     0.0  2020   2020.01
# 45011     8.0  2020   2020.02
# 45450     4.7  2020   2020.03
# 45382     5.2  2020   2020.04
# 46317     0.7  2020   2020.05
# 47962     0.0  2020   2020.07
# 48136     0.0  2020   2020.08
# 48424     0.0  2020   2020.09
# 6398      0.0  2015   2015.04
# 4332      0.9  2015   2015.05
# 6795      0.0  2015   2015.06
# 6964      0.0  2015   2015.07
# 7172      0.0  2015   2015.08
# 7352      0.0  2015   2015.09
# 7732      0.0  2015   2015.11
# 4096      1.2  2015   2015.13
# 2032      7.7  2015   2015.14
# 4509      0.4  2015   2015.15
#
# [48504 rows x 10 columns]

# %%
#Create Function which allows you to easily filter the dataframe
"""
Arguments:
    df : pandas.Dataframe
        the main data frame you pass to the filter function
    players: list (optional)
        a list of player names
    year: list (optional)
        a list of years for which you want data
    position: list (optional)
        a list of positions for which you want data
    team: list (optional)
        a list of teams for which you want data
    not_points: list (optional)
        a list of point values you want to exclude (ex. may want to exclude zero point games)

"""
    



def choose_roster(df, players=[], year=[], position=[],team=[], not_points=[]):
    #filter based on player name
    if len(players)>0:    
        df=df[df['Player'].isin(players)]
    
    #filter based on year
    if len(year)>0:
        df=df[df['Year'].isin(year)]
     
    #filter based on position
    if len(position)>0:
        df=df[df['Position'].isin(position)]
    
    #filter based on team
    if len(team)>0:
        df=df[df['Team'].isin(team)]
    
    #remove entries with certain point values    
    if len(not_points)>0:
        df=df[~df['Points'].isin(not_points)] 
        
    return df

# %%
#combined_df_2[combined_df_2["Team"]].distinct

# %%
choose_roster(combined_df_2, team=['NYJ'],position=["TE"],year=["2020"])
# Out:
#       Position         Player  Week Team  Opp  Opp Position Rank  Salary  \
# 45445       TE  Chris Herndon     1  NYJ  BUF                  5    4700
# 46211       TE  Chris Herndon     2  NYJ   SF                  5    5100
# 45620       TE  Chris Herndon     3  NYJ  IND                  1    5000
# 46024       TE  Chris Herndon     4  NYJ  DEN                 21    4800
# 45656       TE  Chris Herndon     5  NYJ  ARI                 16    4800
# 47751       TE  Chris Herndon     6  NYJ  MIA                  5    4700
# 47932       TE  Chris Herndon     7  NYJ  BUF                 30    4600
# 48497       TE  Chris Herndon     8  NYJ   KC                 14    4400
# 46552       TE   Daniel Brown     1  NYJ  BUF                  5    4000
# 46794       TE   Daniel Brown     2  NYJ   SF                  5    4000
# 47072       TE   Daniel Brown     3  NYJ  IND                  1    4000
# 47378       TE   Daniel Brown     4  NYJ  DEN                 21    4000
# 47248       TE   Daniel Brown     5  NYJ  ARI                 16    4000
# 47748       TE   Daniel Brown     6  NYJ  MIA                  5    4000
# 47930       TE   Daniel Brown     7  NYJ  BUF                 30    4000
# 48175       TE   Daniel Brown     8  NYJ   KC                 14    4000
# 46551       TE   Ryan Griffin     1  NYJ  BUF                  5    4300
# 46792       TE   Ryan Griffin     2  NYJ   SF                  5    4100
# 47069       TE   Ryan Griffin     3  NYJ  IND                  1    4100
# 45827       TE   Ryan Griffin     4  NYJ  DEN                 21    4100
# 47246       TE   Ryan Griffin     5  NYJ  ARI                 16    4100
# 45775       TE   Ryan Griffin     6  NYJ  MIA                  5    4100
# 47928       TE   Ryan Griffin     7  NYJ  BUF                 30    4100
# 48172       TE   Ryan Griffin     8  NYJ   KC                 14    4100
# 46557       TE   Trevon Wesco     1  NYJ  BUF                  5    4000
# 46798       TE   Trevon Wesco     2  NYJ   SF                  5    4000
# 47076       TE   Trevon Wesco     3  NYJ  IND                  1    4000
# 47382       TE   Trevon Wesco     4  NYJ  DEN                 21    4000
# 46220       TE   Trevon Wesco     5  NYJ  ARI                 16    4000
# 47754       TE   Trevon Wesco     6  NYJ  MIA                  5    4100
# 47935       TE   Trevon Wesco     7  NYJ  BUF                 30    4100
# 48178       TE   Trevon Wesco     8  NYJ   KC                 14    4100
#
#        Points  Year Year/Week
# 45445     4.7  2020   2020.01
# 46211     1.0  2020   2020.02
# 45620     3.6  2020   2020.03
# 46024     1.6  2020   2020.04
# 45656     3.4  2020   2020.05
# 47751     0.0  2020   2020.06
# 47932     0.0  2020   2020.07
# 48497    -1.2  2020   2020.08
# 46552     0.0  2020   2020.01
# 46794     0.0  2020   2020.02
# 47072     0.0  2020   2020.03
# 47378     0.0  2020   2020.04
# 47248     0.0  2020   2020.05
# 47748     0.0  2020   2020.06
# 47930     0.0  2020   2020.07
# 48175     0.0  2020   2020.08
# 46551     0.0  2020   2020.01
# 46792     0.0  2020   2020.02
# 47069     0.0  2020   2020.03
# 45827     2.5  2020   2020.04
# 47246     0.0  2020   2020.05
# 45775     2.7  2020   2020.06
# 47928     0.0  2020   2020.07
# 48172     0.0  2020   2020.08
# 46557     0.0  2020   2020.01
# 46798     0.0  2020   2020.02
# 47076     0.0  2020   2020.03
# 47382     0.0  2020   2020.04
# 46220     1.0  2020   2020.05
# 47754     0.0  2020   2020.06
# 47935     0.0  2020   2020.07
# 48178     0.0  2020   2020.08

# %%
#Visualization of Player Production Per Week
choose_roster(combined_df_2,not_points=[0]).hvplot.scatter(x='Year/Week',y="Points",ylabel='Points',groupby='Player', rot=90)
# Out:
# :DynamicMap   [Player]
#    :Scatter   [Year/Week]   (Points)

# %%
choose_roster(combined_df_2,not_points=[0]).hvplot.box(y="Points",by="Year",groupby='Player', rot=90)
# Out:
# :DynamicMap   [Player]
#    :BoxWhisker   [Year]   (Points)

# %%
(choose_roster(combined_df_2,not_points=[0],position=["TE","WR","QB","RB"]).sort_values(by="Year").groupby(["Year","Position","Player"]).mean()).hvplot.box(y="Points",by="Position",groupby='Year', rot=90)
# Out:
# :DynamicMap   [Year]
#    :BoxWhisker   [Position]   (Points)

# %%
(choose_roster(combined_df_2,not_points=[0],position=["TE","WR","QB","RB"]).sort_values(by="Year").groupby(["Year","Position","Player"]).mean()).hvplot.box(y="Points",by="Year",groupby="Position",rot=90)
# Out:
# :DynamicMap   [Position]
#    :BoxWhisker   [Year]   (Points)

# %%
#(choose_roster(combined_df_2,not_points=[0],position=["TE","WR","QB","RB"]).sort_values(by="Points").groupby(["Year","Player"]).mean()).hvplot.box(y="Points",by="Player",groupby="Year",rot=90)
# Out:
# :DynamicMap   [Year]
#    :BoxWhisker   [Player]   (Points)

# %%
player_1=choose_roster(combined_df_2,players=['Christian McCaffrey','A.J. Brown',"Drew Brees", "Alvin Kamara","Mark Andrews","Tyreek Hill","Kenny Golladay"],year=[2018,2019,2020],not_points=[0])
player_1
# Out:
#       Position        Player  Week Team  Opp  Opp Position Rank  Salary  \
# 36606       WR    A.J. Brown     1  TEN  CLE                 11    5100
# 38173       WR    A.J. Brown     2  TEN  IND                 16    5400
# 39545       WR    A.J. Brown     3  TEN  JAX                 21    5200
# 35564       WR    A.J. Brown     4  TEN  ATL                 12    4700
# 38256       WR    A.J. Brown     5  TEN  BUF                  3    5600
# 38390       WR    A.J. Brown     6  TEN  DEN                  4    5400
# 36985       WR    A.J. Brown     7  TEN  LAC                  6    5300
# 37182       WR    A.J. Brown     8  TEN   TB                 30    5500
# 36846       WR    A.J. Brown     9  TEN  CAR                 14    5500
# 38839       WR    A.J. Brown    10  TEN   KC                  8    5500
# 35641       WR    A.J. Brown    12  TEN  JAX                 12    5300
# 37658       WR    A.J. Brown    13  TEN  IND                 19    5300
# 35360       WR    A.J. Brown    14  TEN  OAK                 22    5400
# 35644       WR    A.J. Brown    15  TEN  HOU                 19    6200
# 36175       WR    A.J. Brown    16  TEN   NO                 27    7200
# 35703       WR    A.J. Brown    17  TEN  HOU                 21    7200
# 45208       WR    A.J. Brown     1  TEN  DEN                  9    6700
# 44291       WR    A.J. Brown     5  TEN  BUF                 19    6500
# 44192       WR    A.J. Brown     6  TEN  HOU                 18    6500
# 44076       WR    A.J. Brown     7  TEN  PIT                 26    6800
# 44773       WR    A.J. Brown     8  TEN  CIN                 18    7500
# 44279       WR    A.J. Brown     9  TEN  CHI                  3    7600
# 27347       RB  Alvin Kamara     1   NO   TB                 28    8700
# 28239       RB  Alvin Kamara     2   NO  CLE                 28    9000
# 27497       RB  Alvin Kamara     3   NO  ATL                 25    8700
# 27348       RB  Alvin Kamara     4   NO  NYG                  8    9100
# 29878       RB  Alvin Kamara     5   NO  WAS                 13    9100
# 28294       RB  Alvin Kamara     7   NO  BAL                  1    8200
# 27619       RB  Alvin Kamara     8   NO  MIN                  9    8000
# 27393       RB  Alvin Kamara     9   NO  LAR                  9    8000
# ...        ...           ...   ...  ...  ...                ...     ...
# 28015       WR   Tyreek Hill     7   KC  CIN                 18    7800
# 29185       WR   Tyreek Hill     8   KC  DEN                 11    7800
# 28812       WR   Tyreek Hill     9   KC  CLE                 24    7800
# 27432       WR   Tyreek Hill    10   KC  ARI                  6    7600
# 27349       WR   Tyreek Hill    11   KC  LAR                 18    7900
# 29838       WR   Tyreek Hill    13   KC  OAK                 17    8400
# 27898       WR   Tyreek Hill    14   KC  BAL                  4    8200
# 29698       WR   Tyreek Hill    15   KC  LAC                  7    8400
# 28723       WR   Tyreek Hill    16   KC  SEA                 22    8000
# 27511       WR   Tyreek Hill    17   KC  OAK                 18    7800
# 38491       WR   Tyreek Hill     1   KC  JAX                  1    7600
# 35586       WR   Tyreek Hill     6   KC  HOU                 24    7400
# 36152       WR   Tyreek Hill     7   KC  DEN                  3    7900
# 36676       WR   Tyreek Hill     8   KC   GB                 13    7400
# 35538       WR   Tyreek Hill     9   KC  MIN                 19    7700
# 35422       WR   Tyreek Hill    10   KC  TEN                 11    8000
# 37297       WR   Tyreek Hill    13   KC  OAK                 27    8300
# 36854       WR   Tyreek Hill    14   KC   NE                  1    8300
# 35653       WR   Tyreek Hill    15   KC  DEN                  7    7900
# 36919       WR   Tyreek Hill    16   KC  CHI                  5    8100
# 37196       WR   Tyreek Hill    17   KC  LAC                  4    8200
# 44550       WR   Tyreek Hill     1   KC  HOU                 20    8100
# 44219       WR   Tyreek Hill     2   KC  LAC                  5    8000
# 44251       WR   Tyreek Hill     3   KC  BAL                  1    8100
# 44462       WR   Tyreek Hill     4   KC   NE                 27       0
# 44336       WR   Tyreek Hill     5   KC   LV                 15    8200
# 45552       WR   Tyreek Hill     6   KC  BUF                 18    8300
# 44452       WR   Tyreek Hill     7   KC  DEN                 18    8000
# 44085       WR   Tyreek Hill     8   KC  NYJ                 11    8100
# 44011       WR   Tyreek Hill     9   KC  CAR                  5    8300
#
#        Points  Year Year/Week
# 36606    11.5  2019   2019.01
# 38173     4.0  2019   2019.02
# 39545     0.9  2019   2019.03
# 35564    22.9  2019   2019.04
# 38256     3.7  2019   2019.05
# 38390     3.3  2019   2019.06
# 36985     9.2  2019   2019.07
# 37182     8.1  2019   2019.08
# 36846    10.1  2019   2019.09
# 38839     2.2  2019    2019.1
# 35641    21.5  2019   2019.12
# 37658     6.0  2019   2019.13
# 35360    31.1  2019   2019.14
# 35644    21.4  2019   2019.15
# 36175    14.8  2019   2019.16
# 35703    20.4  2019   2019.17
# 45208     6.4  2020   2020.01
# 44291    17.7  2020   2020.05
# 44192    20.1  2020   2020.06
# 44076    24.3  2020   2020.07
# 44773    10.4  2020   2020.08
# 44279    18.1  2020   2020.09
# 27347    38.6  2018   2018.01
# 28239    14.9  2018   2018.02
# 27497    26.5  2018   2018.03
# 27348    38.6  2018   2018.04
# 29878     5.4  2018   2018.05
# 28294    14.5  2018   2018.07
# 27619    23.1  2018   2018.08
# 27393    31.6  2018   2018.09
# ...       ...   ...       ...
# 28015    17.1  2018   2018.07
# 29185     8.5  2018   2018.08
# 28812    10.5  2018   2018.09
# 27432    29.2  2018    2018.1
# 27349    38.5  2018   2018.11
# 29838     5.5  2018   2018.13
# 27898    18.5  2018   2018.14
# 29698     6.1  2018   2018.15
# 28723    11.1  2018   2018.16
# 27511    26.1  2018   2018.17
# 38491     3.1  2019   2019.01
# 35586    22.5  2019   2019.06
# 36152    14.9  2019   2019.07
# 36676    11.1  2019   2019.08
# 35538    23.5  2019   2019.09
# 35422    27.5  2019    2019.1
# 37297     7.6  2019   2019.13
# 36854    10.0  2019   2019.14
# 35653    21.3  2019   2019.15
# 36919     9.7  2019   2019.16
# 37196     8.1  2019   2019.17
# 44550    13.1  2020   2020.01
# 44219    19.3  2020   2020.02
# 44251    18.7  2020   2020.03
# 44462    14.4  2020   2020.04
# 44336    16.8  2020   2020.05
# 45552     4.0  2020   2020.06
# 44452    14.5  2020   2020.07
# 44085    23.8  2020   2020.08
# 44011    28.6  2020   2020.09
#
# [237 rows x 10 columns]

# %%
num_sims=500
games=13

MC_roster=MCSimulation(
    roster=player_1,
    number_simulation=num_sims,
    number_game=games


)

# %%
MC_roster.calc_points()
# Out:
# Running Monte Carlo simulation number 0.
# Running Monte Carlo simulation number 10.
# Running Monte Carlo simulation number 20.
# Running Monte Carlo simulation number 30.
# Running Monte Carlo simulation number 40.
# Running Monte Carlo simulation number 50.
# Running Monte Carlo simulation number 60.
# Running Monte Carlo simulation number 70.
# Running Monte Carlo simulation number 80.
# Running Monte Carlo simulation number 90.
# Running Monte Carlo simulation number 100.
# Running Monte Carlo simulation number 110.
# Running Monte Carlo simulation number 120.
# Running Monte Carlo simulation number 130.
# Running Monte Carlo simulation number 140.
# Running Monte Carlo simulation number 150.
# Running Monte Carlo simulation number 160.
# Running Monte Carlo simulation number 170.
# Running Monte Carlo simulation number 180.
# Running Monte Carlo simulation number 190.
# Running Monte Carlo simulation number 200.
# Running Monte Carlo simulation number 210.
# Running Monte Carlo simulation number 220.
# Running Monte Carlo simulation number 230.
# Running Monte Carlo simulation number 240.
# Running Monte Carlo simulation number 250.
# Running Monte Carlo simulation number 260.
# Running Monte Carlo simulation number 270.
# Running Monte Carlo simulation number 280.
# Running Monte Carlo simulation number 290.
# Running Monte Carlo simulation number 300.
# Running Monte Carlo simulation number 310.
# Running Monte Carlo simulation number 320.
# Running Monte Carlo simulation number 330.
# Running Monte Carlo simulation number 340.
# Running Monte Carlo simulation number 350.
# Running Monte Carlo simulation number 360.
# Running Monte Carlo simulation number 370.
# Running Monte Carlo simulation number 380.
# Running Monte Carlo simulation number 390.
# Running Monte Carlo simulation number 400.
# Running Monte Carlo simulation number 410.
# Running Monte Carlo simulation number 420.
# Running Monte Carlo simulation number 430.
# Running Monte Carlo simulation number 440.
# Running Monte Carlo simulation number 450.
# Running Monte Carlo simulation number 460.
# Running Monte Carlo simulation number 470.
# Running Monte Carlo simulation number 480.
# Running Monte Carlo simulation number 490.
#             0            1            2            3            4    \
# 0    128.117725   140.873471   134.431056   138.666192    73.835683
# 1    236.942519   257.937684   244.042442   256.810309   208.756824
# 2    348.380095   347.617437   334.956837   390.851528   267.261320
# 3    481.645740   465.610726   440.363435   519.447627   391.828864
# 4    587.355214   600.251298   538.825910   658.373398   500.372365
# 5    706.708152   712.920123   633.781102   809.400525   591.188177
# 6    818.099730   797.389407   741.192253   895.242352   731.890262
# 7    949.489996   935.327105   890.591113  1037.593313   879.340075
# 8   1022.109699  1058.183373   954.399447  1145.267091   933.565899
# 9   1127.046175  1137.413568  1071.492467  1219.218966  1066.830511
# 10  1203.826746  1285.906872  1188.142124  1341.430531  1188.952488
# 11  1331.105199  1359.302211  1289.607216  1448.477014  1292.317775
# 12  1447.122919  1480.134851  1381.118073  1566.894218  1378.175543
#
#             5            6            7            8            9    ...  \
# 0     86.465612   133.844475   144.316555    66.045740   118.858247  ...
# 1    193.856708   232.106343   242.109466   172.245764   185.901375  ...
# 2    305.908984   345.136999   366.378822   312.123181   324.936489  ...
# 3    403.760671   463.518567   498.238702   401.710236   424.555440  ...
# 4    534.951069   594.265573   610.887358   459.653212   555.269895  ...
# 5    660.922932   734.565457   764.134610   587.188758   655.171326  ...
# 6    778.585479   889.681310   841.653018   659.559354   770.267573  ...
# 7    897.831535  1025.836580   955.118566   795.892883   858.132373  ...
# 8   1042.652318  1140.137618  1057.664465   867.969647   988.178653  ...
# 9   1146.545958  1230.661830  1162.724788  1001.686060  1114.205633  ...
# 10  1255.492250  1303.214181  1251.508261  1098.399667  1225.450388  ...
# 11  1378.278950  1396.857633  1364.612931  1257.027485  1353.250097  ...
# 12  1531.912444  1518.401555  1456.177850  1390.802946  1435.267390  ...
#
#             490          491          492          493          494  \
# 0    116.512434   104.168810   131.771875   108.296710   163.846889
# 1    204.248532   218.622700   229.865755   249.920335   284.619985
# 2    284.890305   361.584587   329.886891   334.288983   386.830096
# 3    448.594347   467.669587   425.721997   448.974234   509.625311
# 4    566.001411   577.045472   536.507910   546.809713   638.882522
# 5    706.672608   688.399940   648.188133   675.720943   729.991646
# 6    822.480417   791.573577   731.768654   771.603086   817.817298
# 7    954.129913   919.120889   859.935730   882.721776   932.048125
# 8   1067.523207  1038.910097  1003.851333  1003.396671  1039.177341
# 9   1212.983815  1135.462881  1125.512844  1136.063113  1166.145600
# 10  1337.255747  1231.755010  1249.511090  1239.477504  1302.573505
# 11  1467.520557  1335.165328  1397.167644  1359.148209  1383.076798
# 12  1584.168463  1414.872028  1539.073498  1517.619317  1506.394123
#
#             495          496          497          498          499
# 0     72.453784   116.469923    93.513367   125.733440   152.063474
# 1    167.819392   245.050134   222.675476   224.518220   289.750373
# 2    293.201154   339.718859   303.277550   315.495812   421.511931
# 3    390.957348   432.015654   434.749443   385.930761   500.266854
# 4    490.564947   565.624523   493.811575   499.766607   657.851875
# 5    581.738510   673.777999   630.453191   618.167871   773.242487
# 6    702.751318   780.705377   731.202507   714.765469   889.612170
# 7    782.553040   864.072816   854.296939   821.311679   977.220862
# 8    887.667658  1005.120194   933.669512   947.199862  1121.725997
# 9    998.174548  1129.680944  1011.228407  1067.932988  1179.519869
# 10  1121.066916  1233.243244  1125.975349  1191.510575  1274.272267
# 11  1210.227433  1366.582206  1227.956080  1370.565388  1382.164587
# 12  1322.750277  1513.617985  1354.430052  1460.690310  1551.390799
#
# [13 rows x 500 columns]

# %%
MC_roster.plot_weekly_simulation()

# %%
MC_roster.plot_szn_simulation()

# %%
MC_roster.plot_szn_distribution()

# %%
MC_roster.plot_avg_szn_distribution()

# %%
#MC_roster.plot_avg_szn_distribution()+MC_roster.plot_avg_szn_distribution()

#gitl

# %%
MC_roster.summarize_szn_points()
# Out:
# count            500.000000
# mean            1491.274442
# std               80.073629
# min             1259.190507
# 25%             1439.209235
# 50%             1488.547539
# 75%             1546.218701
# max             1712.832241
# 95% CI Lower    1322.579093
# 95% CI Upper    1636.919084
# Name: 12, dtype: float64

# %%
MC_roster.summarize_avg_szn_points()
# Out:
# count           500.000000
# mean            114.713419
# std               6.159510
# min              96.860808
# 25%             110.708403
# 50%             114.503657
# 75%             118.939900
# max             131.756326
# 95% CI Lower    101.736853
# 95% CI Upper    125.916853
# Name: 12, dtype: float64
