# %%
# Import the pathlib and csv library
# initial imports
import os
import pandas as pd
import matplotlib.pyplot as plt
import plotly.express as px
import hvplot.pandas
from pathlib import Path
from dotenv import load_dotenv
import random
import numpy as np


# %matplotlib inline

# %%
os.getcwd()
# Out:
# 'C:\\Users\\avign\\Desktop\\Project1'

# %%
#Setting the different CSV paths
data_2015_path = Path("./Resources/Historic_Data/fanduel_salary_production/NFL-HistoricalProduction_2015.csv")
data_2016_path = Path("./Resources/Historic_Data/fanduel_salary_production/NFL-HistoricalProduction_2016.csv")
data_2017_path = Path("./Resources/Historic_Data/fanduel_salary_production/NFL-HistoricalProduction_2017.csv")
data_2018_path = Path("./Resources/Historic_Data/fanduel_salary_production/NFL-HistoricalProduction_2018.csv")
data_2019_path = Path("./Resources/Historic_Data/fanduel_salary_production/NFL-HistoricalProduction_2019.csv")
data_2020_path = Path("./Resources/Historic_Data/fanduel_salary_production/NFL-HistoricalProduction_2020.csv")

# %%
#Reading in the CSV into into seperate dataframes
df_1 = pd.read_csv(data_2015_path)
df_2 = pd.read_csv(data_2016_path)
df_3 = pd.read_csv(data_2017_path)
df_4 = pd.read_csv(data_2018_path)
df_5 = pd.read_csv(data_2019_path)
df_6 = pd.read_csv(data_2020_path)

# %%
#Appending a column "Year" for each dataframe
df_1['Year'] = 2015

df_2['Year'] = 2016

df_3['Year'] = 2017

df_4['Year'] = 2018

df_5['Year'] = 2019

df_6['Year'] = 2020

# %%
#Concating all dataframes into one 
combined_df = pd.concat([df_1, df_2, df_3, df_4, df_5, df_6], axis='rows', join='inner')
combined_df.reset_index(inplace=True)

# %%
#Drop Columns
combined_df.drop(['DKSal','DK Points','index'], axis = 1, inplace=True)
combined_df
# Out:
#         P              Player  Week Team  Opp  Opp Position Rank  FDSal  \
# 0      RB       David Johnson    15  ARI  PHI                 20   6500
# 1      RB     Devonta Freeman     3  ATL  DAL                 10   6500
# 2      WR            AJ Green     3  CIN  BAL                 29   8000
# 3      RB        Thomas Rawls    11  SEA   SF                 26   5600
# 4      WR       Antonio Brown    15  PIT  DEN                  1   8800
# 5      WR      Allen Robinson    13  JAX  TEN                 17   8000
# 6      RB   DeAngelo Williams     9  PIT  OAK                 15   6500
# 7      RB        Lamar Miller     7  MIA  HOU                 23   6700
# 8      WR       Antonio Brown     9  PIT  OAK                 12   8700
# 9      WR         Steve Smith     3  BAL  CIN                  6   7100
# 10     WR        Doug Baldwin    12  SEA  PIT                 23   5300
# 11     RB     Devonta Freeman     4  ATL  HOU                  9   7200
# 12     RB         Doug Martin     5   TB  JAX                 15   6400
# 13     WR    Odell Beckham Jr     8  NYG   NO                 18   8700
# 14     WR         Julio Jones     3  ATL  DAL                  4   9000
# 15     WR       Antonio Brown    13  PIT  IND                 21   9000
# 16     RB     Jeremy Langford    10  CHI   LA                 11   6200
# 17     WR    Larry Fitzgerald     2  ARI  CHI                 28   5900
# 18     RB      Danny Woodhead    15   SD  MIA                 29   5300
# 19     WR       Antonio Brown    10  PIT  CLE                 17   8700
# 20     WR    Odell Beckham Jr    14  NYG  MIA                 24   9300
# 21     WR       Antonio Brown     2  PIT   SF                  9   9200
# 22     WR        Randall Cobb     3   GB   KC                 32   8200
# 23     WR     DeAndre Hopkins     6  HOU  JAX                  8   8500
# 24     RB     Adrian Peterson    12  MIN  ATL                 27   9000
# 25     RB     Devonta Freeman     6  ATL   NO                 24   8000
# 26     WR    Emmanuel Sanders    15  DEN  PIT                 27   7100
# 27     WR        Keenan Allen     3   SD  MIN                  2   7600
# 28     WR      Calvin Johnson    12  DET  PHI                 31   8200
# 29     RB         Carlos Hyde     1   SF  MIN                  0   7300
# ...    ..                 ...   ...  ...  ...                ...    ...
# 40654  WR       Pharoh Cooper     6  CAR  CHI                  2   4500
# 40655  WR       Curtis Samuel     6  CAR  CHI                  2   5100
# 40656  FB          Alex Armah     6  CAR  CHI                 13   4500
# 40657  TE      Colin Thompson     6  CAR  CHI                 23      0
# 40658  WR     Brandon Zylstra     6  CAR  CHI                  2   4500
# 40659  WR        Ted Ginn Jr.     6  CHI  CAR                  4   4500
# 40660  TE    Demetrius Harris     6  CHI  CAR                  4   4200
# 40661  TE          J.P. Holtz     6  CHI  CAR                  4   4000
# 40662  WR          Javon Wims     6  CHI  CAR                  4   4600
# 40663  RB           Ryan Nall     6  CHI  CAR                 30   4500
# 40664  WR        Riley Ridley     6  CHI  CAR                  4   4500
# 40665  RB      Artavis Pierce     6  CHI  CAR                 30   4500
# 40666  TE        Nick Vannett     1  DEN  TEN                 27   4000
# 40667  RB         J.J. Taylor     2   NE  SEA                 11   4600
# 40668  RB      Trenton Cannon     5  CAR  ATL                 19   4500
# 40669  WR    Jakeem Grant Sr.     5  MIA   SF                  5   4600
# 40670  RB      Jordan Wilkins     6  IND  CIN                 21   4600
# 40671  RB     Jerick McKinnon     7   SF   NE                  5   5500
# 40672  RB       Ty Montgomery     1   NO   TB                  2   4600
# 40673  RB     Ke'Shawn Vaughn     5   TB  CHI                 17   5000
# 40674  RB  Adrian Killins Jr.     4  PHI   SF                  2   4500
# 40675  WR         Mike Thomas     5  CIN  BAL                 10   4700
# 40676  RB     Darwin Thompson     3   KC  BAL                  1   4500
# 40677  FB      Patrick Ricard     1  BAL  CLE                 25   4500
# 40678  WR      Cedrick Wilson     8  DAL  PHI                 21   4800
# 40679  TE       Chris Herndon     8  NYJ   KC                 14   4400
# 40680  RB     Benny Snell Jr.     2  PIT  DEN                  9   4600
# 40681  WR      DeAndre Carter     4  HOU  MIN                 29   4500
# 40682  WR      Dede Westbrook     7  JAX  LAC                 12   4500
# 40683  WR        Dante Pettis     8   SF  SEA                 32   4500
#
#        FD Points  Year
# 0           42.9  2015
# 1           39.8  2015
# 2           39.7  2015
# 3           39.0  2015
# 4           38.9  2015
# 5           38.3  2015
# 6           37.5  2015
# 7           37.1  2015
# 8           37.1  2015
# 9           37.1  2015
# 10          35.5  2015
# 11          35.4  2015
# 12          35.3  2015
# 13          35.0  2015
# 14          34.4  2015
# 15          33.8  2015
# 16          33.7  2015
# 17          33.2  2015
# 18          33.0  2015
# 19          32.9  2015
# 20          32.1  2015
# 21          32.0  2015
# 22          31.8  2015
# 23          31.8  2015
# 24          31.7  2015
# 25          31.6  2015
# 26          31.5  2015
# 27          31.3  2015
# 28          31.3  2015
# 29          31.2  2015
# ...          ...   ...
# 40654        0.0  2020
# 40655        0.0  2020
# 40656        0.0  2020
# 40657        0.0  2020
# 40658        0.0  2020
# 40659        0.0  2020
# 40660        0.0  2020
# 40661        0.0  2020
# 40662        0.0  2020
# 40663        0.0  2020
# 40664        0.0  2020
# 40665        0.0  2020
# 40666       -0.1  2020
# 40667       -0.1  2020
# 40668       -0.1  2020
# 40669       -0.1  2020
# 40670       -0.1  2020
# 40671       -0.1  2020
# 40672       -0.4  2020
# 40673       -0.5  2020
# 40674       -0.5  2020
# 40675       -0.8  2020
# 40676       -0.9  2020
# 40677       -1.1  2020
# 40678       -1.1  2020
# 40679       -1.2  2020
# 40680       -1.4  2020
# 40681       -2.0  2020
# 40682       -2.0  2020
# 40683       -2.0  2020
#
# [40684 rows x 9 columns]

# %%
#Check for null values within Dataframe
combined_df.isnull().sum()
# Out:
# P                    0
# Player               0
# Week                 0
# Team                 0
# Opp                  0
# Opp Position Rank    0
# FDSal                0
# FD Points            0
# Year                 0
# dtype: int64

# %%
combined_df.dtypes
# Out:
# P                     object
# Player                object
# Week                   int64
# Team                  object
# Opp                   object
# Opp Position Rank      int64
# FDSal                  int64
# FD Points            float64
# Year                   int64
# dtype: object

# %%
#Appending a column "Year" for each dataframe
combined_df['Year/Week'] = combined_df['Year']+combined_df['Week']/100
combined_df.round(decimals = 2)
combined_df['Year/Week'] = combined_df['Year/Week'].apply(str)
combined_df_2 = combined_df.sort_values(by=['Player', 'Year/Week'])
combined_df_2
# Out:
#         P         Player  Week Team  Opp  Opp Position Rank  FDSal  FD Points  \
# 30758  WR     A.J. Brown     1  TEN  CLE                 11   5100       11.5
# 32201  WR     A.J. Brown     2  TEN  IND                 16   5400        4.0
# 33565  WR     A.J. Brown     3  TEN  JAX                 21   5200        0.9
# 29994  WR     A.J. Brown     4  TEN  ATL                 12   4700       22.9
# 32302  WR     A.J. Brown     5  TEN  BUF                  3   5600        3.7
# 32450  WR     A.J. Brown     6  TEN  DEN                  4   5400        3.3
# 31095  WR     A.J. Brown     7  TEN  LAC                  6   5300        9.2
# 31274  WR     A.J. Brown     8  TEN   TB                 30   5500        8.1
# 30954  WR     A.J. Brown     9  TEN  CAR                 14   5500       10.1
# 32883  WR     A.J. Brown    10  TEN   KC                  8   5500        2.2
# 30051  WR     A.J. Brown    12  TEN  JAX                 12   5300       21.5
# 31705  WR     A.J. Brown    13  TEN  IND                 19   5300        6.0
# 29885  WR     A.J. Brown    14  TEN  OAK                 22   5400       31.1
# 30053  WR     A.J. Brown    15  TEN  HOU                 19   6200       21.4
# 30405  WR     A.J. Brown    16  TEN   NO                 27   7200       14.8
# 30088  WR     A.J. Brown    17  TEN  HOU                 21   7200       20.4
# 38098  WR     A.J. Brown     1  TEN  DEN                  9   6700        6.4
# 40026  WR     A.J. Brown     2  TEN  JAX                 10   6600        0.0
# 40189  WR     A.J. Brown     3  TEN  MIN                 31   6500        0.0
# 37385  WR     A.J. Brown     5  TEN  BUF                 19   6500       17.7
# 37321  WR     A.J. Brown     6  TEN  HOU                 18   6500       20.1
# 37261  WR     A.J. Brown     7  TEN  PIT                 26   6800       24.3
# 37734  WR     A.J. Brown     8  TEN  CIN                 18   7500       10.4
# 38864  RB    A.J. Dillon     1   GB  MIN                 14   4700        1.4
# 38792  RB    A.J. Dillon     2   GB  DET                  6   4500        1.7
# 40263  RB    A.J. Dillon     3   GB   NO                 13   4500        0.0
# 39124  RB    A.J. Dillon     4   GB  ATL                 13   4500        0.3
# 38553  RB    A.J. Dillon     6   GB   TB                  8   4500        3.1
# 38966  RB    A.J. Dillon     7   GB  HOU                 32   4500        1.1
# 38372  RB    A.J. Dillon     8   GB  MIN                 16   4800        4.2
# ...    ..            ...   ...  ...  ...                ...    ...        ...
# 33261  WR      Zay Jones     4  BUF   NE                  1   4700        1.4
# 35399  WR      Zay Jones     5  BUF  TEN                  7   4500        0.0
# 36003  WR      Zay Jones     7  OAK   GB                 15   4500        0.0
# 32306  WR      Zay Jones     8  OAK  HOU                 29   4500        3.7
# 32229  WR      Zay Jones     9  OAK  DET                 21   4800        3.9
# 33173  WR      Zay Jones    10  OAK  LAC                  8   4800        1.5
# 32221  WR      Zay Jones    11  OAK  CIN                 15   4800        4.0
# 33183  WR      Zay Jones    12  OAK  NYJ                 30   4800        1.5
# 32780  WR      Zay Jones    13  OAK   KC                  7   4700        2.4
# 33549  WR      Zay Jones    14  OAK  TEN                 17   4700        1.0
# 33511  WR      Zay Jones    15  OAK  JAX                 14   4700        1.0
# 32583  WR      Zay Jones    16  OAK  LAC                  3   4600        2.9
# 32501  WR      Zay Jones    17  OAK  DEN                  7   4700        3.1
# 39767  WR      Zay Jones     1   LV  CAR                 19   4800        0.0
# 37932  WR      Zay Jones     2   LV   NO                 19   4500        8.0
# 38306  WR      Zay Jones     3   LV   NE                 29   4500        4.7
# 38243  WR      Zay Jones     4   LV  BUF                 22   4500        5.2
# 39073  WR      Zay Jones     5   LV   KC                  1   4500        0.7
# 39435  WR      Zay Jones     7   LV   TB                  5   4500        0.0
# 39577  WR      Zay Jones     8   LV  CLE                 30   4500        0.0
# 6382   RB  Zurlon Tipton     4  IND  JAX                 26      0        0.0
# 3799   RB  Zurlon Tipton     5  IND  HOU                  0      0        0.9
# 6694   RB  Zurlon Tipton     6  IND   NE                 10      0        0.0
# 4833   RB  Zurlon Tipton     7  IND   NO                 27      0        0.0
# 4997   RB  Zurlon Tipton     8  IND  CAR                 20      0        0.0
# 5142   RB  Zurlon Tipton     9  IND  DEN                 13      0        0.0
# 5443   RB  Zurlon Tipton    11  IND  ATL                 25      0        0.0
# 3590   RB  Zurlon Tipton    13  IND  PIT                  2      0        1.2
# 1552   RB  Zurlon Tipton    14  IND  JAX                 18      0        7.7
# 3973   RB  Zurlon Tipton    15  IND  HOU                 19      0        0.4
#
#        Year Year/Week
# 30758  2019   2019.01
# 32201  2019   2019.02
# 33565  2019   2019.03
# 29994  2019   2019.04
# 32302  2019   2019.05
# 32450  2019   2019.06
# 31095  2019   2019.07
# 31274  2019   2019.08
# 30954  2019   2019.09
# 32883  2019    2019.1
# 30051  2019   2019.12
# 31705  2019   2019.13
# 29885  2019   2019.14
# 30053  2019   2019.15
# 30405  2019   2019.16
# 30088  2019   2019.17
# 38098  2020   2020.01
# 40026  2020   2020.02
# 40189  2020   2020.03
# 37385  2020   2020.05
# 37321  2020   2020.06
# 37261  2020   2020.07
# 37734  2020   2020.08
# 38864  2020   2020.01
# 38792  2020   2020.02
# 40263  2020   2020.03
# 39124  2020   2020.04
# 38553  2020   2020.06
# 38966  2020   2020.07
# 38372  2020   2020.08
# ...     ...       ...
# 33261  2019   2019.04
# 35399  2019   2019.05
# 36003  2019   2019.07
# 32306  2019   2019.08
# 32229  2019   2019.09
# 33173  2019    2019.1
# 32221  2019   2019.11
# 33183  2019   2019.12
# 32780  2019   2019.13
# 33549  2019   2019.14
# 33511  2019   2019.15
# 32583  2019   2019.16
# 32501  2019   2019.17
# 39767  2020   2020.01
# 37932  2020   2020.02
# 38306  2020   2020.03
# 38243  2020   2020.04
# 39073  2020   2020.05
# 39435  2020   2020.07
# 39577  2020   2020.08
# 6382   2015   2015.04
# 3799   2015   2015.05
# 6694   2015   2015.06
# 4833   2015   2015.07
# 4997   2015   2015.08
# 5142   2015   2015.09
# 5443   2015   2015.11
# 3590   2015   2015.13
# 1552   2015   2015.14
# 3973   2015   2015.15
#
# [40684 rows x 10 columns]

# %%
#Visualization of Player Production Per Week
combined_df_2.hvplot.scatter(x='Year/Week',y="FD Points",ylabel='Points',groupby='Player', rot=90)
# Out:
# :DynamicMap   [Player]
#    :Scatter   [Year/Week]   (FD Points)
